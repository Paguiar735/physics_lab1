# %%
# Remover o comentário das duas linhas abaixo em caso seja usado compiladores mais avançados ou offline.
# !pip install tabulate==0.8.7 --user
# !pip install sympy==1.6.2 --user
# !pip install scipy==1.5.2 --user

#########################################################
#--[Cálculo Numérico (Unidade 3) - Trabalho (Parte 1)]--#
#########################################################
#-----------------[Método dos Trapézios]----------------#
#########################################################

#
##
###
###########################
# 2 - Definição das Funções
###########################
####
###
#

def interface():
    horizontal_line(30, "Início do Script", 1, 2)
    border_msg('Integração pelo Método dos Trapézios v1.0')
    print("\n\u2022 Opções Disponíveis\n")
    print("1. Definição do Método (Digite 1)")
    print("2. Exibir resolução das Questões do Exercício (Digite 2)")
    print("3. Aplicar o Método em uma Função (Digite 3)\n")

    r = input("\u2022 Escolha uma opção: ")
    print("")
    if r == "1":
        print("\u2192 Opção Selecionada:", r, "\n\n")
        statement_of_rule()
    if r == "2":
        print("\u2192 Opção Selecionada:", r, "\n\n")
        answer_key()
    if r == "3":
        print("\u2192 Opção Selecionada:", r, "\n\n")
        application_of_method()
    if (r != "1") and (r != "2") and (r != "3"):
        print("\u2192 Opção Inválida")

def border_msg(msg):
    row = len(msg)+2
    h = ''.join(['+'] + ['-' *row] + ['+'])
    result= h + '\n'"| "+msg+" |"'\n' + h + "\n"
    print(result)

def horizontal_line(n, msg, u, b):
  n = int(n/2)
  print("\n"*u)
  print("-"*n + "[ " + msg + " ]" + "-"*n)
  print("\n"*b)

#
##
#####################################
# 1 - Opção 1 (Média e Desvio Padrão)
#####################################
##
#

def f_deviation_list():
    deviation_list = []
    while 0 == 0:
        a = input("Insira a medida número " + str(i) + ": ")
        if a == "q" or a == "Q":
            break
    deviation_list.append(float(a))
    return deviation_list

def f_number_elements(deviation_list): # Tamanho da Lista, ou seja, seu número de elementos
    number_elements = len(deviation_list)
    print("- Número de Elementos:", number_elements)
    return number_elements

def f_sum_elements(number_elements): # Soma de todos os elementos na lista
    sum_elements = 0
    for i in range(0, number_elements):
        sum_elements = sum_elements + list1[i]
    return sum_elements

def f_arith_mean(sum_elements, number_elements): # Média dos Valores Obtidos
    arith_mean = float(sum_elements/number_elements)
    print("- Média dos Valores Obtidos:", arith_mean)
    return arith_mean

def f_standard_deviation(deviation_list, number_elements, arith_mean):# Desvio Padrão Amostral da Média
    s = 0
    for i in range(0, number_elements):
        s = s + (deviation_list[i] - arith_mean)**2
        i = i + 1
    d = (s/(number_elements-1))**(1/2)
    print("- Desvio Padrão Amostral:", d)
    d = (d/(number_elements*(number_elements-1)))**(1/2) # Desvio Padrão Amostral da Média Vinculado à Incerteza
    print("- Desvio Padrão Amostral Corrigido:", d)

#
##
###
########################
# 3 - Início do Programa
########################
####
###
#

interface()

#########################################################
#-[Criado por Pedro Victor Aguiar da Silva em 14/10/20]-#
#########################################################

# %%
# Remover o comentário das duas linhas abaixo em caso seja usado compiladores mais avançados ou offline.
# !pip install tabulate==0.8.7 --user
# !pip install sympy==1.6.2 --user
# !pip install scipy==1.5.2 --user

#########################################################
#--[Cálculo Numérico (Unidade 3) - Trabalho (Parte 1)]--#
#########################################################
#-----------------[Método dos Trapézios]----------------#
#########################################################
